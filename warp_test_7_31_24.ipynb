# %%
# !pip install warp-lang matplotlib
# Out:
# Collecting warp-lang
#   Downloading warp_lang-1.3.1-py3-none-manylinux2014_x86_64.whl.metadata (23 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from warp-lang) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading warp_lang-1.3.1-py3-none-manylinux2014_x86_64.whl (65.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 MB 10.2 MB/s eta 0:00:00
# Installing collected packages: warp-lang
# Successfully installed warp-lang-1.3.1

# %%
# !export LC_ALL=C.UTF-8
# !export LANG=C.UTF-8

# %%
# !pip install usd-core
# Out:
# Collecting usd-core
#   Downloading usd_core-24.8-cp310-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Downloading usd_core-24.8-cp310-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.6/25.6 MB 55.5 MB/s eta 0:00:00
# Installing collected packages: usd-core
# Successfully installed usd-core-24.8

# %%
import warp as wp
import warp.render


@wp.func
def sdf_create_box(pos: wp.vec3, size: wp.vec3):
    """Creates a SDF box primitive."""
    # https://iquilezles.org/articles/distfunctions
    q = wp.vec3(
        wp.abs(pos[0]) - size[0],
        wp.abs(pos[1]) - size[1],
        wp.abs(pos[2]) - size[2],
    )
    qp = wp.vec3(wp.max(q[0], 0.0), wp.max(q[1], 0.0), wp.max(q[2], 0.0))
    return wp.length(qp) + wp.min(wp.max(q[0], wp.max(q[1], q[2])), 0.0)


@wp.func
def sdf_create_torus(pos: wp.vec3, major_radius: float, minor_radius: float):
    """Creates a SDF torus primitive."""
    # https://iquilezles.org/articles/distfunctions
    q = wp.vec2(wp.length(wp.vec2(pos[0], pos[2])) - major_radius, pos[1])
    return wp.length(q) - minor_radius


@wp.func
def sdf_translate(pos: wp.vec3, offset: wp.vec3):
    """Translates a SDF position vector with an offset."""
    return pos - offset


@wp.func
def sdf_rotate(pos: wp.vec3, angles: wp.vec3):
    """Rotates a SDF position vector using Euler angles."""
    rot = wp.quat_rpy(
        wp.radians(angles[0]),
        wp.radians(angles[1]),
        wp.radians(angles[2]),
    )
    return wp.quat_rotate_inv(rot, pos)


@wp.func
def sdf_smooth_min(a: float, b: float, radius: float):
    """Creates a SDF torus primitive."""
    # https://iquilezles.org/articles/smin
    h = wp.max(radius - wp.abs(a - b), 0.0) / radius
    return wp.min(a, b) - h * h * h * radius * (1.0 / 6.0)


@wp.kernel(enable_backward=False)
def make_field(
    torus_altitude: float,
    torus_major_radius: float,
    torus_minor_radius: float,
    smooth_min_radius: float,
    dim: int,
    time: float,
    out_data: wp.array3d(dtype=float),
):
    """Kernel to generate a SDF volume based on primitives."""
    i, j, k = wp.tid()

    # Retrieve the position of the current cell in a normalized [-1, 1] range
    # for each dimension.
    pos = wp.vec3(
        2.0 * ((float(i) + 0.5) / float(dim)) - 1.0,
        2.0 * ((float(j) + 0.5) / float(dim)) - 1.0,
        2.0 * ((float(k) + 0.5) / float(dim)) - 1.0,
    )

    box = sdf_create_box(
        sdf_translate(pos, wp.vec3(0.0, -0.7, 0.0)),
        wp.vec3(0.9, 0.3, 0.9),
    )
    torus = sdf_create_torus(
        sdf_rotate(
            sdf_translate(pos, wp.vec3(0.0, torus_altitude, 0.0)),
            wp.vec3(wp.sin(time) * 90.0, wp.cos(time) * 45.0, 0.0),
        ),
        torus_major_radius,
        torus_minor_radius,
    )
    out_data[i, j, k] = sdf_smooth_min(box, torus, smooth_min_radius)


class Example:
    def __init__(self, stage_path="example_marching_cubes.usd", verbose=False):
        self.verbose = verbose

        self.dim = 64
        self.max_verts = int(1e6)
        self.max_tris = int(1e6)

        self.torus_altitude = -0.5
        self.torus_major_radius = 0.5
        self.torus_minor_radius = 0.1
        self.smooth_min_radius = 0.5

        self.fps = 60
        self.frame = 0

        self.field = wp.zeros((self.dim, self.dim, self.dim), dtype=float)
        self.mc = wp.MarchingCubes(self.dim, self.dim, self.dim, self.max_verts, self.max_tris)

        self.renderer = None
        if stage_path:
            self.renderer = wp.render.UsdRenderer(stage_path)

    def step(self):
        with wp.ScopedTimer("step"):
            with wp.ScopedTimer("Update Field", active=self.verbose):
                wp.launch(
                    make_field,
                    dim=self.field.shape,
                    inputs=(
                        self.torus_altitude,
                        self.torus_major_radius,
                        self.torus_minor_radius,
                        self.smooth_min_radius,
                        self.dim,
                        self.frame / self.fps,
                    ),
                    outputs=(self.field,),
                )

            with wp.ScopedTimer("Surface Extraction", active=self.verbose):
                self.mc.surface(self.field, 0.0)

    def render(self):
        if self.renderer is None:
            return

        with wp.ScopedTimer("Render"):
            self.renderer.begin_frame(self.frame / self.fps)
            self.renderer.render_mesh(
                "surface",
                self.mc.verts.numpy(),
                self.mc.indices.numpy(),
                colors=((0.35, 0.55, 0.9),) * len(self.mc.verts),
                update_topology=True,
            )
            self.renderer.end_frame()


if __name__ == "__main__":
    import argparse

    parser = argparse.ArgumentParser(formatter_class=argparse.ArgumentDefaultsHelpFormatter)
    parser.add_argument("--device", type=str, default=None, help="Override the default Warp device.")
    parser.add_argument(
        "--stage_path",
        type=lambda x: None if x == "None" else str(x),
        default="example_marching_cubes.usd",
        help="Path to the output USD file.",
    )
    parser.add_argument("--num_frames", type=int, default=240, help="Total number of frames.")
    parser.add_argument("--verbose", action="store_true", help="Print out additional status messages during execution.")

    args = parser.parse_known_args()[0]

    with wp.ScopedDevice(args.device):
        example = Example(stage_path=args.stage_path, verbose=args.verbose)
        for _ in range(args.num_frames):
            example.step()
            example.render()
            example.frame += 1

        if example.renderer is not None:
            example.renderer.save()
# Out:
# Warp 1.3.1 initialized:
#    CUDA Toolkit 12.5, Driver 12.2
#    Devices:
#      "cpu"      : "x86_64"
#      "cuda:0"   : "NVIDIA L4" (22 GiB, sm_89, mempool enabled)
#    Kernel cache:
#      /root/.cache/warp/1.3.1
#     Module __main__ 7906c95 load on device 'cuda:0' took 467.47 ms  (compiled)
# step took 490.60 ms
# Render took 25.37 ms
# step took 0.39 ms
# Render took 24.24 ms
# step took 0.66 ms
# Render took 24.02 ms
# step took 0.68 ms
# Render took 24.00 ms
# step took 0.62 ms
# Render took 24.16 ms
# step took 0.64 ms
# Render took 23.98 ms
# step took 0.62 ms
# Render took 24.10 ms
# step took 0.63 ms
# Render took 25.15 ms
# step took 0.82 ms
# Render took 24.53 ms
# step took 0.76 ms
# Render took 24.38 ms
# step took 0.73 ms
# Render took 24.19 ms
# step took 0.63 ms
# Render took 24.62 ms
# step took 0.92 ms
# Render took 25.03 ms
# step took 0.63 ms
# Render took 25.44 ms
# step took 0.74 ms
# Render took 24.63 ms
# step took 0.98 ms
# Render took 25.83 ms
# step took 1.04 ms
# Render took 24.85 ms
# step took 0.77 ms
# Render took 25.39 ms
# step took 0.80 ms
# Render took 25.55 ms
# step took 0.80 ms
# Render took 24.80 ms
# step took 0.69 ms
# Render took 25.21 ms
# step took 0.74 ms
# Render took 24.97 ms
# step took 0.78 ms
# Render took 24.96 ms
# step took 0.71 ms
# Render took 26.45 ms
# step took 0.77 ms
# Render took 25.07 ms
# step took 0.76 ms
# Render took 25.20 ms
# step took 0.75 ms
# Render took 25.11 ms
# step took 0.65 ms
# Render took 25.03 ms
# step took 0.64 ms
# Render took 25.29 ms
# step took 0.70 ms
# Render took 26.32 ms
# step took 0.77 ms
# Render took 25.41 ms
# step took 0.64 ms
# Render took 26.95 ms
# step took 0.84 ms
# Render took 25.67 ms
# step took 0.73 ms
# Render took 25.49 ms
# step took 0.67 ms
# Render took 25.66 ms
# step took 0.65 ms
# Render took 27.40 ms
# step took 0.97 ms
# Render took 27.25 ms
# step took 0.59 ms
# Render took 27.40 ms
# step took 0.77 ms
# Render took 27.28 ms
# step took 0.76 ms
# Render took 27.56 ms
# step took 0.83 ms
# Render took 26.56 ms
# step took 0.75 ms
# Render took 26.32 ms
# step took 0.72 ms
# Render took 26.59 ms
# step took 0.75 ms
# Render took 26.19 ms
# step took 0.79 ms
# Render took 26.61 ms
# step took 0.66 ms
# Render took 26.40 ms
# step took 0.84 ms
# Render took 26.30 ms
# step took 0.69 ms
# Render took 27.66 ms
# step took 0.34 ms
# Render took 26.33 ms
# step took 0.68 ms
# Render took 26.36 ms
# step took 0.79 ms
# Render took 26.79 ms
# step took 0.76 ms
# Render took 26.18 ms
# step took 0.65 ms
# Render took 26.63 ms
# step took 0.55 ms
# Render took 26.28 ms
# step took 0.36 ms
# Render took 26.92 ms
# step took 0.73 ms
# Render took 28.39 ms
# step took 0.88 ms
# Render took 26.66 ms
# step took 0.81 ms
# Render took 26.99 ms
# step took 0.74 ms
# Render took 26.32 ms
# step took 0.82 ms
# Render took 27.03 ms
# step took 1.11 ms
# Render took 26.50 ms
# step took 0.76 ms
# Render took 27.08 ms
# step took 0.75 ms
# Render took 26.59 ms
# step took 0.76 ms
# Render took 29.18 ms
# step took 0.82 ms
# Render took 28.46 ms
# step took 0.81 ms
# Render took 26.71 ms
# step took 0.74 ms
# Render took 26.68 ms
# step took 0.69 ms
# Render took 26.76 ms
# step took 0.80 ms
# Render took 26.66 ms
# step took 0.76 ms
# Render took 26.61 ms
# step took 0.80 ms
# Render took 27.01 ms
# step took 0.83 ms
# Render took 28.55 ms
# step took 1.11 ms
# Render took 27.32 ms
# step took 0.76 ms
# Render took 27.00 ms
# step took 0.74 ms
# Render took 26.73 ms
# step took 0.70 ms
# Render took 26.55 ms
# step took 0.68 ms
# Render took 26.24 ms
# step took 0.63 ms
# Render took 27.25 ms
# step took 0.70 ms
# Render took 26.70 ms
# step took 0.74 ms
# Render took 27.48 ms
# step took 1.07 ms
# Render took 27.50 ms
# step took 0.83 ms
# Render took 28.07 ms
# step took 1.28 ms
# Render took 26.47 ms
# step took 0.71 ms
# Render took 26.83 ms
# step took 0.73 ms
# Render took 26.48 ms
# step took 0.63 ms
# Render took 26.98 ms
# step took 0.79 ms
# Render took 26.67 ms
# step took 0.81 ms
# Render took 27.57 ms
# step took 0.78 ms
# Render took 26.35 ms
# step took 0.67 ms
# Render took 26.49 ms
# step took 0.71 ms
# Render took 26.57 ms
# step took 0.71 ms
# Render took 27.91 ms
# step took 0.77 ms
# Render took 29.34 ms
# step took 0.83 ms
# Render took 27.38 ms
# step took 0.78 ms
# Render took 27.58 ms
# step took 0.82 ms
# Render took 28.40 ms
# step took 0.80 ms
# Render took 27.81 ms
# step took 0.83 ms
# Render took 27.45 ms
# step took 0.83 ms
# Render took 28.14 ms
# step took 0.74 ms
# Render took 29.45 ms
# step took 0.86 ms
# Render took 27.68 ms
# step took 0.77 ms
# Render took 26.72 ms
# step took 0.75 ms
# Render took 26.66 ms
# step took 1.35 ms
# Render took 27.35 ms
# step took 0.76 ms
# Render took 26.29 ms
# step took 0.86 ms
# Render took 26.60 ms
# step took 0.76 ms
# Render took 26.75 ms
# step took 0.71 ms
# Render took 26.66 ms
# step took 0.98 ms
# Render took 27.05 ms
# step took 0.81 ms
# Render took 26.90 ms
# step took 1.02 ms
# Render took 28.39 ms
# step took 0.45 ms
# Render took 26.73 ms
# step took 0.82 ms
# Render took 27.16 ms
# step took 0.78 ms
# Render took 26.63 ms
# step took 0.75 ms
# Render took 27.49 ms
# step took 0.79 ms
# Render took 27.93 ms
# step took 0.72 ms
# Render took 25.91 ms
# step took 0.68 ms
# Render took 26.59 ms
# step took 0.75 ms
# Render took 28.55 ms
# step took 0.89 ms
# Render took 26.97 ms
# step took 0.71 ms
# Render took 26.66 ms
# step took 0.47 ms
# Render took 26.75 ms
# step took 0.77 ms
# Render took 26.48 ms
# step took 0.66 ms
# Render took 26.56 ms
# step took 0.68 ms
# Render took 27.11 ms
# step took 0.79 ms
# Render took 26.48 ms
# step took 0.72 ms
# Render took 27.64 ms
# step took 0.81 ms
# Render took 26.77 ms
# step took 0.79 ms
# Render took 27.15 ms
# step took 0.77 ms
# Render took 26.65 ms
# step took 0.66 ms
# Render took 26.58 ms
# step took 0.63 ms
# Render took 26.99 ms
# step took 0.70 ms
# Render took 26.60 ms
# step took 0.78 ms
# Render took 26.53 ms
# step took 0.76 ms
# Render took 27.39 ms
# step took 0.79 ms
# Render took 26.32 ms
# step took 0.71 ms
# Render took 41.94 ms
# step took 1.03 ms
# Render took 33.86 ms
# step took 0.78 ms
# Render took 27.11 ms
# step took 0.72 ms
# Render took 26.49 ms
# step took 0.79 ms
# Render took 26.86 ms
# step took 0.78 ms
# Render took 27.54 ms
# step took 0.79 ms
# Render took 26.49 ms
# step took 0.66 ms
# Render took 26.58 ms
# step took 0.65 ms
# Render took 26.84 ms
# step took 0.76 ms
# Render took 26.37 ms
# step took 0.70 ms
# Render took 26.50 ms
# step took 0.69 ms
# Render took 26.31 ms
# step took 0.64 ms
# Render took 26.55 ms
# step took 0.68 ms
# Render took 27.42 ms
# step took 0.80 ms
# Render took 26.66 ms
# step took 0.75 ms
# Render took 27.64 ms
# step took 0.75 ms
# Render took 26.43 ms
# step took 0.63 ms
# Render took 26.39 ms
# step took 0.78 ms
# Render took 26.63 ms
# step took 0.70 ms
# Render took 25.81 ms
# step took 0.66 ms
# Render took 25.91 ms
# step took 0.64 ms
# Render took 26.49 ms
# step took 0.46 ms
# Render took 25.75 ms
# step took 0.77 ms
# Render took 25.55 ms
# step took 0.96 ms
# Render took 26.12 ms
# step took 1.01 ms
# Render took 26.73 ms
# step took 0.74 ms
# Render took 25.98 ms
# step took 0.69 ms
# Render took 25.64 ms
# step took 0.67 ms
# Render took 25.44 ms
# step took 0.63 ms
# Render took 27.28 ms
# step took 0.34 ms
# Render took 25.09 ms
# step took 0.65 ms
# Render took 26.01 ms
# step took 0.80 ms
# Render took 25.43 ms
# step took 0.71 ms
# Render took 25.28 ms
# step took 0.63 ms
# Render took 25.00 ms
# step took 0.63 ms
# Render took 24.92 ms
# step took 0.63 ms
# Render took 25.15 ms
# step took 0.62 ms
# Render took 27.15 ms
# step took 0.78 ms
# Render took 24.89 ms
# step took 0.74 ms
# Render took 24.76 ms
# step took 0.69 ms
# Render took 24.95 ms
# step took 0.82 ms
# Render took 24.47 ms
# step took 0.74 ms
# Render took 24.53 ms
# step took 0.52 ms
# Render took 24.47 ms
# step took 0.73 ms
# Render took 24.67 ms
# step took 0.73 ms
# Render took 24.55 ms
# step took 0.85 ms
# Render took 25.37 ms
# step took 0.73 ms
# Render took 24.47 ms
# step took 0.63 ms
# Render took 24.81 ms
# step took 0.92 ms
# Render took 24.53 ms
# step took 0.97 ms
# Render took 24.50 ms
# step took 0.73 ms
# Render took 24.41 ms
# step took 0.61 ms
# Render took 24.27 ms
# step took 0.71 ms
# Render took 25.03 ms
# step took 0.88 ms
# Render took 25.07 ms
# step took 0.78 ms
# Render took 24.12 ms
# step took 0.67 ms
# Render took 24.38 ms
# step took 0.68 ms
# Render took 24.23 ms
# step took 0.58 ms
# Render took 24.40 ms
# step took 0.71 ms
# Render took 24.28 ms
# step took 0.61 ms
# Render took 24.78 ms
# step took 0.84 ms
# Render took 26.07 ms
# step took 0.59 ms
# Render took 25.87 ms
# step took 0.74 ms
# Render took 24.78 ms
# step took 0.79 ms
# Render took 24.57 ms
# step took 0.70 ms
# Render took 24.88 ms
# step took 0.47 ms
# Render took 24.44 ms
# step took 0.75 ms
# Render took 24.82 ms
# step took 0.71 ms
# Render took 25.14 ms
# step took 0.67 ms
# Render took 25.55 ms
# step took 0.88 ms
# Render took 27.78 ms
# step took 0.75 ms
# Render took 25.31 ms
# step took 0.76 ms
# Render took 25.31 ms
# step took 0.73 ms
# Render took 25.40 ms
# step took 0.67 ms
# Render took 25.36 ms
# step took 0.67 ms
# Render took 25.34 ms
# step took 0.72 ms
# Render took 25.20 ms
# step took 0.63 ms
# Render took 26.34 ms
# step took 0.91 ms
# Render took 27.63 ms
# step took 0.77 ms
# Render took 25.18 ms
# step took 0.61 ms
# Render took 25.23 ms
# step took 0.62 ms
# Render took 25.66 ms
# step took 0.63 ms
# Render took 25.68 ms
# step took 0.75 ms
# Render took 25.55 ms
# step took 0.69 ms
# Render took 26.17 ms
# step took 0.71 ms
# Render took 27.11 ms
# step took 1.05 ms
# Render took 27.37 ms
# step took 0.74 ms
# Render took 26.28 ms
# step took 0.72 ms
# Render took 26.26 ms
# step took 0.61 ms
# Render took 26.48 ms
# step took 0.68 ms
# Render took 27.06 ms
# step took 0.75 ms
# Render took 26.79 ms
# step took 0.69 ms
# Render took 26.36 ms
# step took 0.47 ms
# Render took 27.89 ms
# step took 0.94 ms
# Render took 27.25 ms
# step took 0.68 ms
# Render took 33.01 ms
# step took 0.85 ms
# Render took 27.95 ms
# step took 0.76 ms
# Render took 26.88 ms
# step took 0.68 ms
# Render took 26.33 ms
# step took 0.63 ms
# Render took 26.74 ms
# step took 0.63 ms
# Render took 26.58 ms
# step took 1.23 ms
# Render took 28.12 ms
# step took 0.77 ms
# Render took 26.62 ms
# step took 0.81 ms
# Render took 26.57 ms
# Saved the USD stage file at `/content/example_marching_cubes.usd`

# %%
import subprocess
import locale

# Set the locale to UTF-8
locale.setlocale(locale.LC_ALL, 'C.UTF-8')

# Run the pip install command
subprocess.run(['pip', 'install', '--upgrade', 'pyglet'], check=True)
# Out:
# CompletedProcess(args=['pip', 'install', '--upgrade', 'pyglet'], returncode=0)

# %%
import numpy as np

import warp as wp
import warp.render


class Example:
    def __init__(self, num_tiles=4, custom_tile_arrangement=False):
        self.renderer = wp.render.OpenGLRenderer(vsync=False)
        instance_ids = []

        if custom_tile_arrangement:
            positions = []
            sizes = []
        else:
            positions = None
            sizes = None

        if num_tiles > 1:
            # set up instances to hide one of the capsules in each tile
            for i in range(num_tiles):
                instances = [j for j in np.arange(13) if j != i + 2]
                instance_ids.append(instances)
                if custom_tile_arrangement:
                    angle = np.pi * 2.0 / num_tiles * i
                    positions.append((int(np.cos(angle) * 150 + 250), int(np.sin(angle) * 150 + 250)))
                    sizes.append((150, 150))
            self.renderer.setup_tiled_rendering(instance_ids, tile_positions=positions, tile_sizes=sizes)

        self.renderer.render_ground()

    def render(self):
        time = self.renderer.clock_time
        self.renderer.begin_frame(time)
        for i in range(10):
            self.renderer.render_capsule(
                f"capsule_{i}",
                [i - 5.0, np.sin(time + i * 0.2), -3.0],
                [0.0, 0.0, 0.0, 1.0],
                radius=0.5,
                half_height=0.8,
            )
        self.renderer.render_cylinder(
            "cylinder",
            [3.2, 1.0, np.sin(time + 0.5)],
            np.array(wp.quat_from_axis_angle(wp.vec3(1.0, 0.0, 0.0), wp.sin(time + 0.5))),
            radius=0.5,
            half_height=0.8,
        )
        self.renderer.render_cone(
            "cone",
            [-1.2, 1.0, 0.0],
            np.array(wp.quat_from_axis_angle(wp.vec3(0.707, 0.707, 0.0), time)),
            radius=0.5,
            half_height=0.8,
        )
        self.renderer.end_frame()


if __name__ == "__main__":
    import argparse
    import distutils.util

    parser = argparse.ArgumentParser(formatter_class=argparse.ArgumentDefaultsHelpFormatter)
    parser.add_argument("--device", type=str, default=None, help="Override the default Warp device.")
    parser.add_argument("--num_tiles", type=int, default=4, help="Number of viewports to render in a single frame.")
    parser.add_argument(
        "--show_plot",
        type=lambda x: bool(distutils.util.strtobool(x.strip())),
        default=True,
        help="Display the pixels in an additional matplotlib figure.",
    )
    parser.add_argument("--render_mode", type=str, choices=("depth", "rgb"), default="depth", help="")
    parser.add_argument(
        "--split_up_tiles",
        type=lambda x: bool(distutils.util.strtobool(x.strip())),
        default=True,
        help="Whether to split tiles into subplots when --show_plot is True.",
    )
    parser.add_argument("--custom_tile_arrangement", action="store_true", help="Apply custom tile arrangement.")

    args = parser.parse_known_args()[0]

    with wp.ScopedDevice(args.device):
        example = Example(num_tiles=args.num_tiles, custom_tile_arrangement=args.custom_tile_arrangement)

        channels = 1 if args.render_mode == "depth" else 3

        if args.show_plot:
            import matplotlib.pyplot as plt

            if args.split_up_tiles:
                pixels = wp.zeros(
                    (args.num_tiles, example.renderer.tile_height, example.renderer.tile_width, channels),
                    dtype=wp.float32,
                )
                ncols = int(np.ceil(np.sqrt(args.num_tiles)))
                nrows = int(np.ceil(args.num_tiles / float(ncols)))
                img_plots = []
                aspect_ratio = example.renderer.tile_height / example.renderer.tile_width
                fig, axes = plt.subplots(
                    ncols=ncols,
                    nrows=nrows,
                    constrained_layout=True,
                    figsize=(ncols * 3.5, nrows * 3.5 * aspect_ratio),
                    squeeze=False,
                    sharex=True,
                    sharey=True,
                    num=1,
                )
                tile_temp = np.zeros(
                    (example.renderer.tile_height, example.renderer.tile_width, channels), dtype=np.float32
                )
                for dim in range(ncols * nrows):
                    ax = axes[dim // ncols, dim % ncols]
                    if dim >= args.num_tiles:
                        ax.axis("off")
                        continue
                    if args.render_mode == "depth":
                        img_plots.append(
                            ax.imshow(
                                tile_temp,
                                vmin=example.renderer.camera_near_plane,
                                vmax=example.renderer.camera_far_plane,
                            )
                        )
                    else:
                        img_plots.append(ax.imshow(tile_temp))
            else:
                fig = plt.figure(1)
                pixels = wp.zeros(
                    (example.renderer.screen_height, example.renderer.screen_width, channels), dtype=wp.float32
                )
                if args.render_mode == "depth":
                    img_plot = plt.imshow(
                        pixels.numpy(), vmin=example.renderer.camera_near_plane, vmax=example.renderer.camera_far_plane
                    )
                else:
                    img_plot = plt.imshow(pixels.numpy())

            plt.ion()
            plt.show()

        while example.renderer.is_running():
            example.render()

            if args.show_plot and plt.fignum_exists(1):
                if args.split_up_tiles:
                    pixel_shape = (args.num_tiles, example.renderer.tile_height, example.renderer.tile_width, channels)
                else:
                    pixel_shape = (example.renderer.screen_height, example.renderer.screen_width, channels)

                if pixel_shape != pixels.shape:
                    # make sure we resize the pixels array to the right dimensions if the user resizes the window
                    pixels = wp.zeros(pixel_shape, dtype=wp.float32)

                example.renderer.get_pixels(pixels, split_up_tiles=args.split_up_tiles, mode=args.render_mode)

                if args.split_up_tiles:
                    pixels_np = pixels.numpy()
                    for i, img_plot in enumerate(img_plots):
                        img_plot.set_data(pixels_np[i])
                else:
                    img_plot.set_data(pixels.numpy())
                fig.canvas.draw()
                fig.canvas.flush_events()

        example.renderer.clear()
# Out:
# ---------------------------------------------------------------------------
# NoSuchDisplayException                    Traceback (most recent call last)
# <ipython-input-8-6bdc4d0c8be9> in <cell line: 60>()
#      83
#      84     with wp.ScopedDevice(args.device):
# ---> 85         example = Example(num_tiles=args.num_tiles, custom_tile_arrangement=args.custom_tile_arrangement)
#      86
#      87         channels = 1 if args.render_mode == "depth" else 3
#
# <ipython-input-8-6bdc4d0c8be9> in __init__(self, num_tiles, custom_tile_arrangement)
#       7 class Example:
#       8     def __init__(self, num_tiles=4, custom_tile_arrangement=False):
# ----> 9         self.renderer = wp.render.OpenGLRenderer(vsync=False)
#      10         instance_ids = []
#      11
#
# /usr/local/lib/python3.10/dist-packages/warp/render/render_opengl.py in __init__(self, title, scaling, fps, up_axis, screen_width, screen_height, near_plane, far_plane, camera_fov, camera_pos, camera_front, camera_up, background_color, draw_grid, draw_sky, draw_axis, show_info, render_wireframe, render_depth, axis_scale, vsync, headless, enable_backface_culling, enable_mouse_interaction, enable_keyboard_interaction)
#    1019
#    1020             from pyglet import gl
# -> 1021             from pyglet.graphics.shader import Shader, ShaderProgram
#    1022             from pyglet.math import Vec3 as PyVec3
#    1023         except ImportError as e:
#
# /usr/local/lib/python3.10/dist-packages/pyglet/graphics/__init__.py in <module>
#      14
#      15 import pyglet
# ---> 16 from pyglet.gl.gl import (
#      17     GL_TEXTURE0,
#      18     GL_UNSIGNED_BYTE,
#
# /usr/local/lib/python3.10/dist-packages/pyglet/gl/__init__.py in <module>
#     195     # trickery is for circular import
#     196     _pyglet.gl = _sys.modules[__name__]
# --> 197     import pyglet.window  # noqa: F401
#
# /usr/local/lib/python3.10/dist-packages/pyglet/window/__init__.py in <module>
#    1792 if not _is_pyglet_doc_run:
#    1793     pyglet.window = sys.modules[__name__]
# -> 1794     gl._create_shadow_window()  # noqa: SLF001
#    1795
#    1796
#
# /usr/local/lib/python3.10/dist-packages/pyglet/gl/__init__.py in _create_shadow_window()
#     169             """Shadow window does not need a projection."""
#     170
# --> 171     _shadow_window = ShadowWindow()
#     172     _shadow_window.switch_to()
#     173
#
# /usr/local/lib/python3.10/dist-packages/pyglet/gl/__init__.py in __init__(self)
#     164     class ShadowWindow(Window):
#     165         def __init__(self) -> None:
# --> 166             super().__init__(width=1, height=1, visible=False)
#     167
#     168         def _create_projection(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pyglet/window/xlib/__init__.py in __init__(self, *args, **kwargs)
#     166                     self._event_handlers[message] = func
#     167
# --> 168         super().__init__(*args, **kwargs)
#     169
#     170         global _can_detect_autorepeat  # noqa: PLW0603
#
# /usr/local/lib/python3.10/dist-packages/pyglet/window/__init__.py in __init__(self, width, height, caption, resizable, style, fullscreen, visible, vsync, file_drops, display, screen, config, context, mode)
#     499
#     500         if not display:
# --> 501             display = pyglet.canvas.get_display()
#     502
#     503         if not screen:
#
# /usr/local/lib/python3.10/dist-packages/pyglet/canvas/__init__.py in get_display()
#      74
#      75     # Otherwise, create a new display and return it.
# ---> 76     return Display()
#      77
#      78 __all__ = ['Display', 'Screen', 'Canvas', 'ScreenMode', 'get_display']
#
# /usr/local/lib/python3.10/dist-packages/pyglet/canvas/xlib.py in __init__(self, name, x_screen)
#      89         self._display = xlib.XOpenDisplay(name)
#      90         if not self._display:
# ---> 91             raise NoSuchDisplayException(f'Cannot connect to "{name}"')
#      92
#      93         screen_count = xlib.XScreenCount(self._display)
#
# NoSuchDisplayException: Cannot connect to "None"
